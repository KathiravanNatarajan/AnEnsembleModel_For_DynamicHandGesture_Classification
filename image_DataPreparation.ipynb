# %% [markdown]
# ### Image data
# """
# uint8	0 to 255
#
# uint16	0 to 65535
# """

# %% [markdown]
# ### Image resize

# %%
# Opens one image file, resize and write it to a different directory with a different file name
import cv2
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
filename = r'C:\Users\sunka\Desktop\An Ensemble Deep Model to differentiate static hand gestures\DHG2016\images\gesture_1\finger_1\subject_1\essai_1\depth_1.png'

img = cv2.imread(filename)
print(img.shape)
plt.imshow(img)
plt.show()
reshaped_image = cv2.resize(img,(100, 100))
print(reshaped_image.shape)
cv2.imwrite(r'C:\Users\sunka\Desktop\An Ensemble Deep Model to differentiate static hand gestures\DHG2016\reshaped_images\dep.png', reshaped_image)

dep = r'C:\Users\sunka\Desktop\An Ensemble Deep Model to differentiate static hand gestures\DHG2016\reshaped_images\dep.png'

image = mpimg.imread(dep)
plt.imshow(image)
plt.show()

img_matplot = mpimg.imread(filename)
img_matplot_resized_100 = cv2.resize(img_matplot,(100, 100))
img_matplot_resized_200 = cv2.resize(img_matplot,(200, 200))
plt.imshow(img_matplot)
plt.show()
plt.imshow(img_matplot_resized_100)
plt.show()
plt.imshow(img_matplot_resized_200)
plt.show()
cv2.imwrite(r'C:\Users\sunka\Desktop\An Ensemble Deep Model to differentiate static hand gestures\DHG2016\reshaped_images\dep.png', img_matplot_resized_200)

new_img = mpimg.imread(dep)
plt.imshow(new_img)
# Out:
# (480, 640, 3)
# (100, 100, 3)
# True

# %% [markdown]
# ### Image Data Serialization

# %%
data = r'C:\Users\sunka\Desktop\An Ensemble Deep Model to differentiate static hand gestures\DHG2016\reshaped_images'+"\\"+"gesture"

print(data)
# Out:
# C:\Users\sunka\Desktop\An Ensemble Deep Model to differentiate static hand gestures\DHG2016\reshaped_images\gesture

# %%
X = images.astype('float32')

# images/=255
print(images.shape)

X.dump("train_features.pkl")

# %% [markdown]
# ### Labels

# %%
labels_df = pd.read_csv("labels.csv")

labels = pd.get_dummies(labels_df["labels"]).as_matrix()

print(labels.shape)
labels.dump("./data_dump/train_labels.pkl")
